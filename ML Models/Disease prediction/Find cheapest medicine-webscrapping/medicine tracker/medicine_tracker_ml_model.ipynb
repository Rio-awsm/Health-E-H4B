# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import streamlit as st

# Load the dataset
df = pd.read_csv('medicines.csv')

# Preprocess the dataset
# ...

# Define the similarity metric
def similarity(x, y):
    # Compute the cosine similarity between the composition and effectiveness vectors
    return cosine_similarity([x['composition'] + x['effectiveness']], [y['composition'] + y['effectiveness']])[0][0]

# Build the recommendation system
def recommend(medicine):
    # Find the most similar medicines
    similarities = df.apply(lambda x: similarity(x, medicine), axis=1)
    similar_medicines = df.loc[similarities.nlargest(10).index]

    # Return the recommended medicines
    return similar_medicines

# Build the Streamlit app
st.title('Medicine Recommender')

# Add a search box for the medicine name
medicine_name = st.text_input('Enter a medicine name')

# Find the medicine in the dataset
medicine = df.loc[df['name'] == medicine_name]

# If the medicine is found, recommend similar medicines
if not medicine.empty:
    st.subheader('Recommended Medicines')
    recommended_medicines = recommend(medicine)
    for index, row in recommended_medicines.iterrows():
        st.write(row['name'])
else:
    st.write('Medicine not found')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 from sklearn.metrics.pairwise import cosine_similarity
# ----> 3 import streamlit as st
#       5 # Load the dataset
#       6 df = pd.read_csv('medicines.csv')
#
# ModuleNotFoundError: No module named 'streamlit'

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.24.1-py2.py3-none-any.whl (8.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 13.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil<3,>=2 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from streamlit) (2.8.2)
# Collecting pydeck<1,>=0.1.dev5
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 13.6 MB/s eta 0:00:0000:0100:01
# Collecting validators<1,>=0.2
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pillow<10,>=6.2.0 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: numpy<2,>=1 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from streamlit) (1.23.5)
# Requirement already satisfied: tenacity<9,>=8.0.0 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from streamlit) (8.0.1)
# Requirement already satisfied: packaging<24,>=14.1 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from streamlit) (22.0)
# Collecting tzlocal<5,>=1.1
#   Downloading tzlocal-4.3.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.1 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from streamlit) (4.4.0)
# Collecting pympler<2,>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 11.8 MB/s eta 0:00:00
# Collecting protobuf<5,>=3.20
#   Downloading protobuf-4.23.4-cp37-abi3-macosx_10_9_universal2.whl (400 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.3/400.3 kB 9.1 MB/s eta 0:00:0000:01
# Collecting pyarrow>=4.0
#   Downloading pyarrow-12.0.1-cp310-cp310-macosx_11_0_arm64.whl (22.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.6/22.6 MB 6.7 MB/s eta 0:00:0000:0100:01
# Collecting blinker<2,>=1.0.0
#   Using cached blinker-1.6.2-py3-none-any.whl (13 kB)
# Collecting altair<6,>=4.0
#   Downloading altair-5.0.1-py3-none-any.whl (471 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.5/471.5 kB 3.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: toml<2 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from streamlit) (0.10.2)
# Collecting rich<14,>=10.11.0
#   Downloading rich-13.4.2-py3-none-any.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 3.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from streamlit) (6.1)
# Collecting cachetools<6,>=4.0
#   Downloading cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from streamlit) (4.11.3)
# Collecting gitpython!=3.1.19,<4,>=3
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 4.1 MB/s eta 0:00:0000:01
# Requirement already satisfied: requests<3,>=2.4 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from streamlit) (2.28.1)
# Requirement already satisfied: pandas<3,>=0.25 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from streamlit) (1.5.3)
# Requirement already satisfied: click<9,>=7.0 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: jsonschema>=3.0 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: jinja2 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: toolz in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from pandas<3,>=0.25->streamlit) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from python-dateutil<3,>=2->streamlit) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.4->streamlit) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.4->streamlit) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.4->streamlit) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from requests<3,>=2.4->streamlit) (3.4)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 4.6 MB/s eta 0:00:00
# Collecting pygments<3.0.0,>=2.13.0
#   Using cached Pygments-2.15.1-py3-none-any.whl (1.1 MB)
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: decorator>=3.4.0 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from validators<1,>=0.2->streamlit) (5.1.1)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/prabuddhachowdhury/anaconda3/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting tzdata
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 3.7 MB/s eta 0:00:0000:0100:01
# Building wheels for collected packages: validators
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19581 sha256=a67beff227da0b11bb026f3c7eb4bf0c9ecc5f895c8979fd85c93f5216c02a93
#   Stored in directory: /Users/prabuddhachowdhury/Library/Caches/pip/wheels/2d/55/25/123071088f4e466746cbadc923b1a31e08cea99ea9ef6bb35e
# Successfully built validators
# Installing collected packages: validators, tzdata, smmap, pympler, pygments, pyarrow, protobuf, mdurl, cachetools, blinker, pytz-deprecation-shim, pydeck, markdown-it-py, gitdb, tzlocal, rich, gitpython, altair, streamlit
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.11.2
#     Uninstalling Pygments-2.11.2:
#       Successfully uninstalled Pygments-2.11.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.4.1 requires pyqt5<5.16, which is not installed.
# spyder 5.4.1 requires pyqtwebengine<5.16, which is not installed.
# Successfully installed altair-5.0.1 blinker-1.6.2 cachetools-5.3.1 gitdb-4.0.10 gitpython-3.1.31 markdown-it-py-3.0.0 mdurl-0.1.2 protobuf-4.23.4 pyarrow-12.0.1 pydeck-0.8.1b0 pygments-2.15.1 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 rich-13.4.2 smmap-5.0.0 streamlit-1.24.1 tzdata-2023.3 tzlocal-4.3.1 validators-0.20.0

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
import streamlit as st

# Load the dataset
df = pd.read_csv('medicines.csv')

# Preprocess the dataset
# ...

# Define the similarity metric
def similarity(x, y):
    # Compute the cosine similarity between the composition and effectiveness vectors
    return cosine_similarity([x['composition'] + x['effectiveness']], [y['composition'] + y['effectiveness']])[0][0]

# Build the recommendation system
def recommend(medicine):
    # Find the most similar medicines
    similarities = df.apply(lambda x: similarity(x, medicine), axis=1)
    similar_medicines = df.loc[similarities.nlargest(10).index]

    # Return the recommended medicines
    return similar_medicines

# Build the Streamlit app
st.title('Medicine Recommender')

# Add a search box for the medicine name
medicine_name = st.text_input('Enter a medicine name')

# Find the medicine in the dataset
medicine = df.loc[df['name'] == medicine_name]

# If the medicine is found, recommend similar medicines
if not medicine.empty:
    st.subheader('Recommended Medicines')
    recommended_medicines = recommend(medicine)
    for index, row in recommended_medicines.iterrows():
        st.write(row['name'])
else:
    st.write('Medicine not found')
# Out:
# 2023-07-10 15:26:10.644
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/prabuddhachowdhury/Documents/GitHub/doctor_H4B/medicine tracker/ipykernel_launcher.py [ARGUMENTS]
